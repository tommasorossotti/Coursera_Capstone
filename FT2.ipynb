# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
import requests
print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW' # your Foursquare ID
CLIENT_SECRET = 'BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S' # your Foursquare Secret
VERSION = '20180929'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW
# CLIENT_SECRET:BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S

# %%
address = 'Virginia Beach, VA'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# 36.8529841 -75.9774183

# %%
search_query = 'Coffee'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW&client_secret=BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S&ll=36.8529841,-75.9774183&v=20180929&query=Coffee&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e599ead77af03001bfb7747'},
#  'response': {'venues': [{'id': '57487afd498e2665b707a63b',
#     'name': 'Three Ships Coffee Bar and Roastery',
#     'location': {'address': '607 19th St',
#      'crossStreet': 'Mediterranean Street',
#      'lat': 36.846105403127005,
#      'lng': -75.98235051569591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846105403127005,
#        'lng': -75.98235051569591}],
#      'distance': 882,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['607 19th St (Mediterranean Street)',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4b816977f964a52085a430e3',
#     'name': 'Bad Ass Coffee',
#     'location': {'address': '619 18th St',
#      'lat': 36.845091600087486,
#      'lng': -75.98315821519844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.845091600087486,
#        'lng': -75.98315821519844}],
#      'distance': 1016,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['619 18th St',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1312827',
#      'url': 'https://www.grubhub.com/restaurant/bad-ass-coffee-619-18th-street-virginia-beach/1312827?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1312827',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '35383790'},
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4cb1bedfcbab236a5e24ab73',
#     'name': 'Beach Coffee Co.',
#     'location': {'address': '1005 Atlantic Ave',
#      'lat': 36.838952522337316,
#      'lng': -75.97249804295173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.838952522337316,
#        'lng': -75.97249804295173}],
#      'distance': 1622,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1005 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1796491',
#      'url': 'https://www.grubhub.com/restaurant/beach-coffee-1014-atlantic-avenue-virginia-beach/1796491?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1796491',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4ce6d6419f776ea8f9335422',
#     'name': 'Perked Up Coffee Cafe',
#     'location': {'address': '3198 Pacific Avenur',
#      'lat': 36.86015886424331,
#      'lng': -75.98045399704473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.86015886424331,
#        'lng': -75.98045399704473}],
#      'distance': 843,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['3198 Pacific Avenur',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1792330',
#      'url': 'https://www.grubhub.com/restaurant/perked-up-coffee-cafe-3198-pacific-avenue-virginia-beach/1792330?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1792330',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4f321d0319836c91c7b73c2f',
#     'name': 'Cape Henry Coffee',
#     'location': {'address': '3198 Pacific Ave',
#      'lat': 36.860372999999996,
#      'lng': -75.980315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.860372999999996,
#        'lng': -75.980315}],
#      'distance': 862,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['3198 Pacific Ave',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4c7ad1e781bca093a8b60115',
#     'name': 'Maui Wowi Hawaiian Coffee',
#     'location': {'address': '1719 Atlantic Ave',
#      'lat': 36.846164,
#      'lng': -75.974036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846164,
#        'lng': -75.974036}],
#      'distance': 816,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1719 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '5de2c59baf03f3000800d898',
#     'name': 'Fathom Coffee',
#     'location': {'address': '1682 Baltic Ave.',
#      'crossStreet': 'Virginia Beach Ave.',
#      'lat': 36.844055,
#      'lng': -75.97935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.844055,
#        'lng': -75.97935}],
#      'distance': 1008,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1682 Baltic Ave. (Virginia Beach Ave.)',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4ba65919f964a520034939e3',
#     'name': 'Belvedere Coffee Shop',
#     'location': {'address': '3601 Atlantic Ave',
#      'crossStreet': 'at 36th St',
#      'lat': 36.8643338388835,
#      'lng': -75.97895220378987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.8643338388835,
#        'lng': -75.97895220378987}],
#      'distance': 1270,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['3601 Atlantic Ave (at 36th St)',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4b5459abf964a52048b827e3',
#     'name': 'Starbucks',
#     'location': {'address': '241 Laskin Road',
#      'lat': 36.85915482880249,
#      'lng': -75.97897582675576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85915482880249,
#        'lng': -75.97897582675576}],
#      'distance': 700,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['241 Laskin Road',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1471123',
#      'url': 'https://www.grubhub.com/restaurant/starbucks-241-laskin-road-virginia-beach/1471123?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1471123',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4c1fe784a34cd13a231a7d74',
#     'name': 'Courtyard by Marriott',
#     'location': {'address': '3737 Atlantic Ave',
#      'lat': 36.8656956,
#      'lng': -75.9794813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.8656956,
#        'lng': -75.9794813}],
#      'distance': 1426,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['3737 Atlantic Ave',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4b87d477f964a52022ce31e3',
#     'name': 'Java Surf Café & Espresso Bar',
#     'location': {'address': '1807 Mediterranean Ave',
#      'crossStreet': '19th Street',
#      'lat': 36.846027172627124,
#      'lng': -75.98147662979201,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.846027172627124,
#        'lng': -75.98147662979201}],
#      'distance': 854,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1807 Mediterranean Ave (19th Street)',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1470038',
#      'url': 'https://www.grubhub.com/restaurant/java-surf-cafe--espresso-bar-1807-mediterranean-avenue-virginia-beach/1470038?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470038',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4c2f47d266e40f474a92c18b',
#     'name': 'Beach Coffee Co.',
#     'location': {'address': 'Atlantic Avenue',
#      'crossStreet': '10th Street',
#      'lat': 36.883645325477346,
#      'lng': -75.98567133549707,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.883645325477346,
#        'lng': -75.98567133549707}],
#      'distance': 3491,
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Atlantic Avenue (10th Street)',
#       'Virginia Beach, VA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4ba3ae63f964a520ae5338e3',
#     'name': 'Seattles Best Coffee',
#     'location': {'address': '1744 Laskin Rd #24',
#      'lat': 36.85151974152343,
#      'lng': -76.02325931237169,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85151974152343,
#        'lng': -76.02325931237169}],
#      'distance': 4086,
#      'postalCode': '23454',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1744 Laskin Rd #24',
#       'Virginia Beach, VA 23454',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4c0a41557e3fc9285b3ff382',
#     'name': 'Cars and Coffee',
#     'location': {'address': 'Laskin Road',
#      'lat': 36.84971,
#      'lng': -76.03134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.84971,
#        'lng': -76.03134}],
#      'distance': 4816,
#      'postalCode': '23454',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Laskin Road',
#       'Virginia Beach, VA 23454',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1582931591',
#     'hasPerk': False},
#    {'id': '4bbce82f8ec3d13a79671b28',
#     'name': 'Starbucks',
#     'location': {'address': '1612 Laskin Rd',
#      'lat': 36.85273073,
#      'lng': -76.01751118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 36.85273073,
#        'lng': -76.01751118}],
#      'distance': 3571,
#      'postalCode': '23451',
#      'cc': 'US',
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1612 Laskin Rd',
#       'Virginia Beach, VA 23451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1469921',
#      'url': 'https://www.grubhub.com/restaurant/starbucks-1612-laskin-road-virginia-beach/1469921?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469921',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931591',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1312827
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1796491
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...     1792330
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1  /delivery_provider_grubhub_20180129.png
# 2  /delivery_provider_grubhub_20180129.png
# 3  /delivery_provider_grubhub_20180129.png
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                grubhub  https://www.grubhub.com/restaurant/bad-ass-cof...
# 2                grubhub  https://www.grubhub.com/restaurant/beach-coffe...
# 3                grubhub  https://www.grubhub.com/restaurant/perked-up-c...
# 4                    NaN                                                NaN
#
#    hasPerk                        id     location.address  ...  \
# 0    False  57487afd498e2665b707a63b          607 19th St  ...
# 1    False  4b816977f964a52085a430e3          619 18th St  ...
# 2    False  4cb1bedfcbab236a5e24ab73    1005 Atlantic Ave  ...
# 3    False  4ce6d6419f776ea8f9335422  3198 Pacific Avenur  ...
# 4    False  4f321d0319836c91c7b73c2f     3198 Pacific Ave  ...
#
#   location.distance                          location.formattedAddress  \
# 0               882  [607 19th St (Mediterranean Street), Virginia ...
# 1              1016  [619 18th St, Virginia Beach, VA 23451, United...
# 2              1622  [1005 Atlantic Ave, Virginia Beach, VA 23451, ...
# 3               843  [3198 Pacific Avenur, Virginia Beach, VA 23451...
# 4               862  [3198 Pacific Ave, Virginia Beach, VA 23451, U...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 36.84610540312700...    36.846105
# 1  [{'label': 'display', 'lat': 36.84509160008748...    36.845092
# 2  [{'label': 'display', 'lat': 36.83895252233731...    36.838953
# 3  [{'label': 'display', 'lat': 36.86015886424331...    36.860159
# 4  [{'label': 'display', 'lat': 36.86037299999999...    36.860373
#
#    location.lng location.postalCode location.state  \
# 0    -75.982351               23451             VA
# 1    -75.983158               23451             VA
# 2    -75.972498               23451             VA
# 3    -75.980454               23451             VA
# 4    -75.980315               23451             VA
#
#                                   name    referralId venuePage.id
# 0  Three Ships Coffee Bar and Roastery  v-1582931591          NaN
# 1                       Bad Ass Coffee  v-1582931591     35383790
# 2                     Beach Coffee Co.  v-1582931591          NaN
# 3                Perked Up Coffee Cafe  v-1582931591          NaN
# 4                    Cape Henry Coffee  v-1582931591          NaN
#
# [5 rows x 24 columns]

# %%
dataframe.shape
# Out:
# (15, 24)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name   categories                 address  \
# 0   Three Ships Coffee Bar and Roastery  Coffee Shop             607 19th St
# 1                        Bad Ass Coffee  Coffee Shop             619 18th St
# 2                      Beach Coffee Co.  Coffee Shop       1005 Atlantic Ave
# 3                 Perked Up Coffee Cafe         Café     3198 Pacific Avenur
# 4                     Cape Henry Coffee  Coffee Shop        3198 Pacific Ave
# 5             Maui Wowi Hawaiian Coffee         Café       1719 Atlantic Ave
# 6                         Fathom Coffee  Coffee Shop        1682 Baltic Ave.
# 7                 Belvedere Coffee Shop        Diner       3601 Atlantic Ave
# 8                             Starbucks  Coffee Shop         241 Laskin Road
# 9                 Courtyard by Marriott        Hotel       3737 Atlantic Ave
# 10        Java Surf Café & Espresso Bar  Coffee Shop  1807 Mediterranean Ave
# 11                     Beach Coffee Co.  Coffee Shop         Atlantic Avenue
# 12                 Seattles Best Coffee         None      1744 Laskin Rd #24
# 13                      Cars and Coffee         None             Laskin Road
# 14                            Starbucks  Coffee Shop          1612 Laskin Rd
#
#     cc            city        country           crossStreet  distance  \
# 0   US  Virginia Beach  United States  Mediterranean Street       882
# 1   US  Virginia Beach  United States                   NaN      1016
# 2   US  Virginia Beach  United States                   NaN      1622
# 3   US  Virginia Beach  United States                   NaN       843
# 4   US  Virginia Beach  United States                   NaN       862
# 5   US  Virginia Beach  United States                   NaN       816
# 6   US  Virginia Beach  United States   Virginia Beach Ave.      1008
# 7   US  Virginia Beach  United States            at 36th St      1270
# 8   US  Virginia Beach  United States                   NaN       700
# 9   US  Virginia Beach  United States                   NaN      1426
# 10  US  Virginia Beach  United States           19th Street       854
# 11  US  Virginia Beach  United States           10th Street      3491
# 12  US  Virginia Beach  United States                   NaN      4086
# 13  US  Virginia Beach  United States                   NaN      4816
# 14  US  Virginia Beach  United States                   NaN      3571
#
#                                      formattedAddress  \
# 0   [607 19th St (Mediterranean Street), Virginia ...
# 1   [619 18th St, Virginia Beach, VA 23451, United...
# 2   [1005 Atlantic Ave, Virginia Beach, VA 23451, ...
# 3   [3198 Pacific Avenur, Virginia Beach, VA 23451...
# 4   [3198 Pacific Ave, Virginia Beach, VA 23451, U...
# 5   [1719 Atlantic Ave, Virginia Beach, VA 23451, ...
# 6   [1682 Baltic Ave. (Virginia Beach Ave.), Virgi...
# 7   [3601 Atlantic Ave (at 36th St), Virginia Beac...
# 8   [241 Laskin Road, Virginia Beach, VA 23451, Un...
# 9   [3737 Atlantic Ave, Virginia Beach, VA 23451, ...
# 10  [1807 Mediterranean Ave (19th Street), Virgini...
# 11  [Atlantic Avenue (10th Street), Virginia Beach...
# 12  [1744 Laskin Rd #24, Virginia Beach, VA 23454,...
# 13  [Laskin Road, Virginia Beach, VA 23454, United...
# 14  [1612 Laskin Rd, Virginia Beach, VA 23451, Uni...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 36.84610540312700...  36.846105 -75.982351
# 1   [{'label': 'display', 'lat': 36.84509160008748...  36.845092 -75.983158
# 2   [{'label': 'display', 'lat': 36.83895252233731...  36.838953 -75.972498
# 3   [{'label': 'display', 'lat': 36.86015886424331...  36.860159 -75.980454
# 4   [{'label': 'display', 'lat': 36.86037299999999...  36.860373 -75.980315
# 5   [{'label': 'display', 'lat': 36.846164, 'lng':...  36.846164 -75.974036
# 6   [{'label': 'display', 'lat': 36.844055, 'lng':...  36.844055 -75.979350
# 7   [{'label': 'display', 'lat': 36.8643338388835,...  36.864334 -75.978952
# 8   [{'label': 'display', 'lat': 36.85915482880249...  36.859155 -75.978976
# 9   [{'label': 'display', 'lat': 36.8656956, 'lng'...  36.865696 -75.979481
# 10  [{'label': 'display', 'lat': 36.84602717262712...  36.846027 -75.981477
# 11  [{'label': 'display', 'lat': 36.88364532547734...  36.883645 -75.985671
# 12  [{'label': 'display', 'lat': 36.85151974152343...  36.851520 -76.023259
# 13  [{'label': 'display', 'lat': 36.84971, 'lng': ...  36.849710 -76.031340
# 14  [{'label': 'display', 'lat': 36.85273073, 'lng...  36.852731 -76.017511
#
#    postalCode state                        id
# 0       23451    VA  57487afd498e2665b707a63b
# 1       23451    VA  4b816977f964a52085a430e3
# 2       23451    VA  4cb1bedfcbab236a5e24ab73
# 3       23451    VA  4ce6d6419f776ea8f9335422
# 4       23451    VA  4f321d0319836c91c7b73c2f
# 5       23451    VA  4c7ad1e781bca093a8b60115
# 6       23451    VA  5de2c59baf03f3000800d898
# 7       23451    VA  4ba65919f964a520034939e3
# 8       23451    VA  4b5459abf964a52048b827e3
# 9       23451    VA  4c1fe784a34cd13a231a7d74
# 10      23451    VA  4b87d477f964a52022ce31e3
# 11        NaN    VA  4c2f47d266e40f474a92c18b
# 12      23454    VA  4ba3ae63f964a520ae5338e3
# 13      23454    VA  4c0a41557e3fc9285b3ff382
# 14      23451    VA  4bbce82f8ec3d13a79671b28

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Virginia Beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4b5459abf964a52048b827e3' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b5459abf964a52048b827e3?client_id=Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW&client_secret=BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S&v=20180929'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b5459abf964a52048b827e3',
#  'name': 'Starbucks',
#  'contact': {'phone': '7574253162',
#   'formattedPhone': '(757) 425-3162',
#   'twitter': 'starbucks',
#   'facebook': '22092443056',
#   'facebookUsername': 'Starbucks',
#   'facebookName': 'Starbucks'},
#  'location': {'address': '241 Laskin Road',
#   'lat': 36.85915482880249,
#   'lng': -75.97897582675576,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 36.85915482880249,
#     'lng': -75.97897582675576}],
#   'postalCode': '23451',
#   'cc': 'US',
#   'city': 'Virginia Beach',
#   'state': 'VA',
#   'country': 'United States',
#   'formattedAddress': ['241 Laskin Road',
#    'Virginia Beach, VA 23451',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/starbucks/4b5459abf964a52048b827e3',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 32},
#  'url': 'http://www.starbucks.com',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 102,
#   'groups': [{'type': 'others', 'count': 102, 'items': []}],
#   'summary': '102 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.9,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 147,
#  'delivery': {'id': '1471123',
#   'url': 'https://www.grubhub.com/restaurant/starbucks-241-laskin-road-virginia-beach/1471123?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1471123',
#   'provider': {'name': 'grubhub',
#    'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50],
#     'name': '/delivery_provider_grubhub_20180129.png'}}},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 178,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 178,
#     'items': [{'id': '4f670ab0e4b03a7ce33d2b06',
#       'createdAt': 1332153008,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/gbJut8nlvRCwPl-naiMTVda7WbJBMjP4haNTXGTg_N4.jpg',
#       'width': 540,
#       'height': 720,
#       'user': {'id': '427688',
#        'firstName': 'Jeffrey',
#        'lastName': 'R',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/QH21MPTWZ3E2KU5W.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': '31 Ocean',
#  'storeId': '8888',
#  'page': {'pageInfo': {'description': 'Follow Starbucks on Foursquare to check in and earn great badges. Visit enough stores to become the envy of your friends with the Barista Badge.',
#    'banner': 'https://is1.4sqi.net/userpix/EEKNV3AQRAQ4IV3G.png',
#    'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com/'}]}},
#   'user': {'id': '1070527',
#    'firstName': 'Starbucks',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/PM3ZCXLZIG3WZHVC.png'},
#    'type': 'chain',
#    'tips': {'count': 46},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1263819179,
#  'tips': {'count': 32,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 32,
#     'items': [{'id': '4e108a30d22d759bae5a1f9d',
#       'createdAt': 1309706800,
#       'text': "Slowest Starbucks I've ever been to",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4e108a30d22d759bae5a1f9d',
#       'lang': 'en',
#       'likes': {'count': 5,
#        'groups': [{'type': 'others',
#          'count': 5,
#          'items': [{'id': '7456357',
#            'firstName': 'somebodys',
#            'lastName': 's',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/OPKKGSTBG1OPUYZ2.jpg'}},
#           {'id': '5837874',
#            'firstName': 'Allison',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/5837874_iTm4e7U0_ngIx4NHxT9PLE_b_0KrvGaftkQNT9zzZwTwx-Aw9-lcXMUxENMQCV031CTzeZsjK.jpg'}}]}],
#        'summary': '5 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '4173929',
#        'firstName': 'Leanna',
#        'lastName': 'W',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/5Y4BBVSETWZSOJF3.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/aiAxN4',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 8,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 8,
#     'items': [{'id': '50352c1ae4b0b37a457d408e',
#       'name': 'va beach',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '33458297',
#        'firstName': 'Cheryl',
#        'lastName': 'N',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/R3C13MHUIQCFBEPS.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/33458297/list/va-beach',
#       'canonicalUrl': 'https://foursquare.com/user/33458297/list/va-beach',
#       'createdAt': 1345661978,
#       'updatedAt': 1345662359,
#       'followers': {'count': 0},
#       'listItems': {'count': 8,
#        'items': [{'id': 'v4b5459abf964a52048b827e3',
#          'createdAt': 1345662061}]}},
#      {'id': '4e8199aa9adf8adb8a4f0b64',
#       'name': 'Road Trip',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '784115',
#        'firstName': 'Stephen',
#        'lastName': 'G',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/784115-E0OEOOB41T5R5FHM.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/sgilkenson/list/road-trip',
#       'canonicalUrl': 'https://foursquare.com/sgilkenson/list/road-trip',
#       'createdAt': 1317116330,
#       'updatedAt': 1368218603,
#       'followers': {'count': 1},
#       'listItems': {'count': 40,
#        'items': [{'id': 'v4b5459abf964a52048b827e3',
#          'createdAt': 1317457119}]}},
#      {'id': '4eefa6610e01899e023233f8',
#       'name': 'AT&T Wi-Fi Hot Spots- Starbucks #12',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '11852785',
#        'firstName': 'AT&T',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/11852785-I454F2WMF3U2VCYF'},
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/p/att/11852785/list/att-wifi-hot-spots-starbucks-12',
#       'canonicalUrl': 'https://foursquare.com/p/att/11852785/list/att-wifi-hot-spots-starbucks-12',
#       'createdAt': 1324328545,
#       'updatedAt': 1402261446,
#       'logView': True,
#       'followers': {'count': 41},
#       'listItems': {'count': 200,
#        'items': [{'id': 't4ef40455d3e32dc399639d2f',
#          'createdAt': 1324614738}]}}]}]},
#  'hours': {'status': 'Open until 11:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'open': [{'renderedTime': '5:30 AM–10:30 PM'}],
#     'segments': []},
#    {'days': 'Fri–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '5:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 AM–9:30 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–8:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Breakfast & Brunch',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '4f670ab0e4b03a7ce33d2b06',
#   'createdAt': 1332153008,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/gbJut8nlvRCwPl-naiMTVda7WbJBMjP4haNTXGTg_N4.jpg',
#   'width': 540,
#   'height': 720,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '4f670ab0e4b03a7ce33d2b06',
#    'value': -8884128},
#   'highlightTextColor': {'photoId': '4f670ab0e4b03a7ce33d2b06', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
result['response']['venue']['tips']['count']
# Out:
# 32

# %%
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e599e767828ae002823ecef'},
#  'response': {'tips': {'count': 32,
#    'items': [{'id': '55f59230498e062f41a908b5',
#      'createdAt': 1442157104,
#      'text': 'The baristas are very friendly & attentive even when they have a billion things to do. You cats are amazing, 1 of the best #Starbucks spots I visited in VA & MD. #KeepUpTheGoodWork 👍 #Latte ☕️',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/55f59230498e062f41a908b5',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 2,
#      'disagreeCount': 0,
#      'lastVoteText': 'Upvoted Jan 24',
#      'lastUpvoteTimestamp': 1579891011,
#      'todo': {'count': 0},
#      'user': {'id': '23575557',
#       'firstName': 'Angelo',
#       'lastName': 'D',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/23575557_Vxr5wr8X_nbzbmblRASHDEU7ZAsLv0k-9KYTieQbdJouX9eSzg4XY4yt3fHRFHaUBqkX9aoTt.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                                                                text  \
# 0  The baristas are very friendly & attentive even when they have a billion things to do. You cats are amazing, 1 of the best #Starbucks spots I visited in VA & MD. #KeepUpTheGoodWork 👍 #Latte ☕️
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  2           0              55f59230498e062f41a908b5  Angelo
#
#   user.lastName  user.gender   user.id
# 0  D            NaN           23575557

# %%
address = 'Pompano Beach'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# 26.2378597 -80.1247667

# %%
search_query = 'Coffee'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW&client_secret=BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S&ll=26.2378597,-80.1247667&v=20180929&query=Coffee&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e599eb0542890001b73f9e1'},
#  'response': {'venues': [{'id': '561d2581498ee5be35171393',
#     'name': 'Calusa Coffee Roasters',
#     'location': {'address': '161 E Commercial Blvd',
#      'lat': 26.188696003134485,
#      'lng': -80.14533512628987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.188696003134485,
#        'lng': -80.14533512628987}],
#      'distance': 5845,
#      'postalCode': '33334',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['161 E Commercial Blvd',
#       'Fort Lauderdale, FL 33334',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '557257',
#      'url': 'https://www.grubhub.com/restaurant/calusa-coffee-roasters-161-e-commercial-blvd-fort-lauderdale/557257?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=557257',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '146701814'},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4e5436f81850048f642da531',
#     'name': 'Beach Roast- Gourmet Cakes & Desserts / Caribbean & Organic Coffees                                                              Home Delivery  / Mail Order  /  Wholesale',
#     'location': {'lat': 26.231684356442894,
#      'lng': -80.10282039642334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.231684356442894,
#        'lng': -80.10282039642334}],
#      'distance': 2296,
#      'postalCode': '33062',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Pompano Beach, FL 33062', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '34930870'},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4e551eb518508c109233b4c6',
#     'name': 'BeachRoast Bake Shop & Coffee Roastery (Bakery)',
#     'location': {'address': '655 N Federal Hwy',
#      'lat': 26.23726609433151,
#      'lng': -80.1028847694397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.23726609433151,
#        'lng': -80.1028847694397}],
#      'distance': 2185,
#      'postalCode': '33062',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['655 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '5d331f6596a1bb000713bed8',
#     'name': 'Carmela Coffee Company',
#     'location': {'address': '1182 S Powerline Rd',
#      'lat': 26.214993,
#      'lng': -80.155495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.214993,
#        'lng': -80.155495}],
#      'distance': 3986,
#      'postalCode': '33069',
#      'cc': 'US',
#      'neighborhood': 'Cypress Bend',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1182 S Powerline Rd',
#       'Pompano Beach, FL 33069',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1490297',
#      'url': 'https://www.grubhub.com/restaurant/carmela-coffee-company-1182-powerline-road-pompano-beach/1490297?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1490297',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4ba22623f964a5204adf37e3',
#     'name': 'boomerang coffee',
#     'location': {'address': '1631 S Cypress Rd',
#      'crossStreet': 'McNab',
#      'lat': 26.209585743855826,
#      'lng': -80.12333393096924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.209585743855826,
#        'lng': -80.12333393096924}],
#      'distance': 3150,
#      'postalCode': '33060',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1631 S Cypress Rd (McNab)',
#       'Pompano Beach, FL 33060',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '58a622eb0a3d5449dcb753e0',
#     'name': 'Allegro Coffee Company',
#     'location': {'address': '2411 N Federal Hwy',
#      'lat': 26.2612944444444,
#      'lng': -80.0994988888889,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.2612944444444,
#        'lng': -80.0994988888889}],
#      'distance': 3628,
#      'postalCode': '33062',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['2411 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4f32641419836c91c7d32f60',
#     'name': 'Manhattan Gourmet Coffee',
#     'location': {'address': '6472 NW 5th Way',
#      'lat': 26.207023,
#      'lng': -80.15051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.207023,
#        'lng': -80.15051}],
#      'distance': 4288,
#      'postalCode': '33309',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6472 NW 5th Way',
#       'Fort Lauderdale, FL 33309',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '76423579'},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '59be9d5e2079551e2b9d17b2',
#     'name': 'Starbucks',
#     'location': {'lat': 26.202628825623375,
#      'lng': -80.15385356040811,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.202628825623375,
#        'lng': -80.15385356040811}],
#      'distance': 4880,
#      'postalCode': '33309',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['Fort Lauderdale, FL 33309', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1490582',
#      'url': 'https://www.grubhub.com/restaurant/starbucks-850-northwest-62nd-street-fort-lauderdale/1490582?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1490582',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4af080acf964a520b5dc21e3',
#     'name': 'Starbucks',
#     'location': {'address': '423 S Federal Hwy',
#      'lat': 26.22872271,
#      'lng': -80.10301395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.22872271,
#        'lng': -80.10301395}],
#      'distance': 2398,
#      'postalCode': '33062',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['423 S Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1488902',
#      'url': 'https://www.grubhub.com/restaurant/starbucks-423-federal-highway-pompano-beach/1488902?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1488902',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4f71e862e4b03b7fbb2d81e4',
#     'name': "Ricky's Coffee Shop",
#     'location': {'address': '6310 Powerline Rd',
#      'crossStreet': 'NW 63rd St',
#      'lat': 26.205691326539085,
#      'lng': -80.15487019806336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.205691326539085,
#        'lng': -80.15487019806336}],
#      'distance': 4675,
#      'postalCode': '33309',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6310 Powerline Rd (NW 63rd St)',
#       'Fort Lauderdale, FL 33309',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4f3257f319836c91c7ce7069',
#     'name': 'Manhattan Gourmet Coffee',
#     'location': {'address': '6310 Powerline Rd',
#      'lat': 26.204236,
#      'lng': -80.155567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.204236,
#        'lng': -80.155567}],
#      'distance': 4844,
#      'postalCode': '33309',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['6310 Powerline Rd',
#       'Fort Lauderdale, FL 33309',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4bfeb45e34ced13ad5f537b3',
#     'name': 'daily grind coffee shop',
#     'location': {'address': 'sample road',
#      'crossStreet': 'federal highway',
#      'lat': 26.272529,
#      'lng': -80.08931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.272529,
#        'lng': -80.08931}],
#      'distance': 5236,
#      'postalCode': '33064',
#      'cc': 'US',
#      'city': 'Lighthouse PT',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['sample road (federal highway)',
#       'Lighthouse PT, FL 33064',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4b0ca736f964a520994023e3',
#     'name': 'Starbucks',
#     'location': {'address': '1800 N Federal Hwy',
#      'lat': 26.254771744411375,
#      'lng': -80.09993382956327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.254771744411375,
#        'lng': -80.09993382956327}],
#      'distance': 3113,
#      'postalCode': '33062',
#      'cc': 'US',
#      'city': 'Pompano Beach',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1800 N Federal Hwy',
#       'Pompano Beach, FL 33062',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1488387',
#      'url': 'https://www.grubhub.com/restaurant/starbucks-1800-north-federal-highway-pompano-beach/1488387?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1488387',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4f32a1ac19836c91c7ea98dd',
#     'name': 'Starbucks',
#     'location': {'address': '4711 NE 18th Ter',
#      'lat': 26.185463000000002,
#      'lng': -80.121915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.185463000000002,
#        'lng': -80.121915}],
#      'distance': 5839,
#      'postalCode': '33308',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['4711 NE 18th Ter',
#       'Fort Lauderdale, FL 33308',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '4b29518cf964a520d59c24e3',
#     'name': 'Broward College North Campus',
#     'location': {'address': '1000 Coconut Creek Blvd',
#      'lat': 26.240689821714884,
#      'lng': -80.17348835186554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.240689821714884,
#        'lng': -80.17348835186554}],
#      'distance': 4874,
#      'postalCode': '33066',
#      'cc': 'US',
#      'city': 'Coconut Creek',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['1000 Coconut Creek Blvd',
#       'Coconut Creek, FL 33066',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'shortName': 'Community College',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '64256277'},
#     'referralId': 'v-1582931646',
#     'hasPerk': False},
#    {'id': '53aef269498ec970f3cf1265',
#     'name': 'Starbucks',
#     'location': {'address': '3704 N. Ocean Blvd',
#      'lat': 26.173383444326404,
#      'lng': -80.09943507413925,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 26.173383444326404,
#        'lng': -80.09943507413925}],
#      'distance': 7610,
#      'postalCode': '33308',
#      'cc': 'US',
#      'city': 'Fort Lauderdale',
#      'state': 'FL',
#      'country': 'United States',
#      'formattedAddress': ['3704 N. Ocean Blvd',
#       'Fort Lauderdale, FL 33308',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582931646',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.shape
# Out:
# (16, 25)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                                                                                                                                           name  \
# 0   Calusa Coffee Roasters
# 1   Beach Roast- Gourmet Cakes & Desserts / Caribbean & Organic Coffees                                                              Home Delivery  / Mail Order  /  Wholesale
# 2   BeachRoast Bake Shop & Coffee Roastery (Bakery)
# 3   Carmela Coffee Company
# 4   boomerang coffee
# 5   Allegro Coffee Company
# 6   Manhattan Gourmet Coffee
# 7   Starbucks
# 8   Starbucks
# 9   Ricky's Coffee Shop
# 10  Manhattan Gourmet Coffee
# 11  daily grind coffee shop
# 12  Starbucks
# 13  Starbucks
# 14  Broward College North Campus
# 15  Starbucks
#
#                    categories                  address  cc             city  \
# 0   Coffee Shop                161 E Commercial Blvd    US  Fort Lauderdale
# 1   Dessert Shop               NaN                      US  Pompano Beach
# 2   Café                       655 N Federal Hwy        US  Pompano Beach
# 3   Coffee Shop                1182 S Powerline Rd      US  Pompano Beach
# 4   Coffee Shop                1631 S Cypress Rd        US  Pompano Beach
# 5   Coffee Shop                2411 N Federal Hwy       US  Pompano Beach
# 6   Coffee Shop                6472 NW 5th Way          US  Fort Lauderdale
# 7   Coffee Shop                NaN                      US  Fort Lauderdale
# 8   Coffee Shop                423 S Federal Hwy        US  Pompano Beach
# 9   Latin American Restaurant  6310 Powerline Rd        US  Fort Lauderdale
# 10  Coffee Shop                6310 Powerline Rd        US  Fort Lauderdale
# 11  None                       sample road              US  Lighthouse PT
# 12  Coffee Shop                1800 N Federal Hwy       US  Pompano Beach
# 13  Coffee Shop                4711 NE 18th Ter         US  Fort Lauderdale
# 14  Community College          1000 Coconut Creek Blvd  US  Coconut Creek
# 15  Coffee Shop                3704 N. Ocean Blvd       US  Fort Lauderdale
#
#           country      crossStreet  distance  \
# 0   United States  NaN              5845
# 1   United States  NaN              2296
# 2   United States  NaN              2185
# 3   United States  NaN              3986
# 4   United States  McNab            3150
# 5   United States  NaN              3628
# 6   United States  NaN              4288
# 7   United States  NaN              4880
# 8   United States  NaN              2398
# 9   United States  NW 63rd St       4675
# 10  United States  NaN              4844
# 11  United States  federal highway  5236
# 12  United States  NaN              3113
# 13  United States  NaN              5839
# 14  United States  NaN              4874
# 15  United States  NaN              7610
#
#                                                               formattedAddress  \
# 0   [161 E Commercial Blvd, Fort Lauderdale, FL 33334, United States]
# 1   [Pompano Beach, FL 33062, United States]
# 2   [655 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 3   [1182 S Powerline Rd, Pompano Beach, FL 33069, United States]
# 4   [1631 S Cypress Rd (McNab), Pompano Beach, FL 33060, United States]
# 5   [2411 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 6   [6472 NW 5th Way, Fort Lauderdale, FL 33309, United States]
# 7   [Fort Lauderdale, FL 33309, United States]
# 8   [423 S Federal Hwy, Pompano Beach, FL 33062, United States]
# 9   [6310 Powerline Rd (NW 63rd St), Fort Lauderdale, FL 33309, United States]
# 10  [6310 Powerline Rd, Fort Lauderdale, FL 33309, United States]
# 11  [sample road (federal highway), Lighthouse PT, FL 33064, United States]
# 12  [1800 N Federal Hwy, Pompano Beach, FL 33062, United States]
# 13  [4711 NE 18th Ter, Fort Lauderdale, FL 33308, United States]
# 14  [1000 Coconut Creek Blvd, Coconut Creek, FL 33066, United States]
# 15  [3704 N. Ocean Blvd, Fort Lauderdale, FL 33308, United States]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 26.188696003134485, 'lng': -80.14533512628987}]
# 1   [{'label': 'display', 'lat': 26.231684356442894, 'lng': -80.10282039642334}]
# 2   [{'label': 'display', 'lat': 26.23726609433151, 'lng': -80.1028847694397}]
# 3   [{'label': 'display', 'lat': 26.214993, 'lng': -80.155495}]
# 4   [{'label': 'display', 'lat': 26.209585743855826, 'lng': -80.12333393096924}]
# 5   [{'label': 'display', 'lat': 26.2612944444444, 'lng': -80.0994988888889}]
# 6   [{'label': 'display', 'lat': 26.207023, 'lng': -80.15051}]
# 7   [{'label': 'display', 'lat': 26.202628825623375, 'lng': -80.15385356040811}]
# 8   [{'label': 'display', 'lat': 26.22872271, 'lng': -80.10301395}]
# 9   [{'label': 'display', 'lat': 26.205691326539085, 'lng': -80.15487019806336}]
# 10  [{'label': 'display', 'lat': 26.204236, 'lng': -80.155567}]
# 11  [{'label': 'display', 'lat': 26.272529, 'lng': -80.08931}]
# 12  [{'label': 'display', 'lat': 26.254771744411375, 'lng': -80.09993382956327}]
# 13  [{'label': 'display', 'lat': 26.185463000000002, 'lng': -80.121915}]
# 14  [{'label': 'display', 'lat': 26.240689821714884, 'lng': -80.17348835186554}]
# 15  [{'label': 'display', 'lat': 26.173383444326404, 'lng': -80.09943507413925}]
#
#           lat        lng  neighborhood postalCode state  \
# 0   26.188696 -80.145335  NaN           33334      FL
# 1   26.231684 -80.102820  NaN           33062      FL
# 2   26.237266 -80.102885  NaN           33062      FL
# 3   26.214993 -80.155495  Cypress Bend  33069      FL
# 4   26.209586 -80.123334  NaN           33060      FL
# 5   26.261294 -80.099499  NaN           33062      FL
# 6   26.207023 -80.150510  NaN           33309      FL
# 7   26.202629 -80.153854  NaN           33309      FL
# 8   26.228723 -80.103014  NaN           33062      FL
# 9   26.205691 -80.154870  NaN           33309      FL
# 10  26.204236 -80.155567  NaN           33309      FL
# 11  26.272529 -80.089310  NaN           33064      FL
# 12  26.254772 -80.099934  NaN           33062      FL
# 13  26.185463 -80.121915  NaN           33308      FL
# 14  26.240690 -80.173488  NaN           33066      FL
# 15  26.173383 -80.099435  NaN           33308      FL
#
#                           id
# 0   561d2581498ee5be35171393
# 1   4e5436f81850048f642da531
# 2   4e551eb518508c109233b4c6
# 3   5d331f6596a1bb000713bed8
# 4   4ba22623f964a5204adf37e3
# 5   58a622eb0a3d5449dcb753e0
# 6   4f32641419836c91c7d32f60
# 7   59be9d5e2079551e2b9d17b2
# 8   4af080acf964a520b5dc21e3
# 9   4f71e862e4b03b7fbb2d81e4
# 10  4f3257f319836c91c7ce7069
# 11  4bfeb45e34ced13ad5f537b3
# 12  4b0ca736f964a520994023e3
# 13  4f32a1ac19836c91c7ea98dd
# 14  4b29518cf964a520d59c24e3
# 15  53aef269498ec970f3cf1265

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Pompano Beach',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4af080acf964a520b5dc21e3' # Nearest starbucks
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4af080acf964a520b5dc21e3?client_id=Z03AXDAO4CVTCJXCZANIT05WOG3QB3KKN54WL3U1ZGHECUZW&client_secret=BCZN2FCB4HOIBASDZ2PV5QZMTNNRZYT5QNNJ1NR2QKGOVH3S&v=20180929'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4af080acf964a520b5dc21e3',
#  'name': 'Starbucks',
#  'contact': {'phone': '9545453431',
#   'formattedPhone': '(954) 545-3431',
#   'twitter': 'starbucks',
#   'instagram': 'starbucks',
#   'facebook': '22092443056',
#   'facebookUsername': 'Starbucks',
#   'facebookName': 'Starbucks'},
#  'location': {'address': '423 S Federal Hwy',
#   'lat': 26.22872271,
#   'lng': -80.10301395,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 26.22872271,
#     'lng': -80.10301395}],
#   'postalCode': '33062',
#   'cc': 'US',
#   'city': 'Pompano Beach',
#   'state': 'FL',
#   'country': 'United States',
#   'formattedAddress': ['423 S Federal Hwy',
#    'Pompano Beach, FL 33062',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/starbucks/4af080acf964a520b5dc21e3',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 21},
#  'url': 'https://www.starbucks.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 72,
#   'groups': [{'type': 'others', 'count': 72, 'items': []}],
#   'summary': '72 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 8.3,
#  'ratingColor': '73CF42',
#  'ratingSignals': 99,
#  'delivery': {'id': '1488902',
#   'url': 'https://www.grubhub.com/restaurant/starbucks-423-federal-highway-pompano-beach/1488902?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1488902',
#   'provider': {'name': 'grubhub',
#    'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50],
#     'name': '/delivery_provider_grubhub_20180129.png'}}},
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://www.starbucks.com/menu',
#   'mobileUrl': 'https://www.starbucks.com/menu',
#   'externalUrl': 'https://www.starbucks.com/menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 96,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 96,
#     'items': [{'id': '511a58d1e4b0030487f30121',
#       'createdAt': 1360681169,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/15208664_OABwsdJqGi97y8xCZ3UQqsfGzvGJrtYGLu4X7H8oA2s.jpg',
#       'width': 720,
#       'height': 960,
#       'user': {'id': '15208664',
#        'firstName': 'Ashley',
#        'lastName': 'C',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4ROFAQ3MPUYNDE1P.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'Pompano Plaza',
#  'storeId': '8476',
#  'page': {'pageInfo': {'description': 'Follow Starbucks on Foursquare to check in and earn great badges. Visit enough stores to become the envy of your friends with the Barista Badge.',
#    'banner': 'https://is1.4sqi.net/userpix/EEKNV3AQRAQ4IV3G.png',
#    'links': {'count': 1, 'items': [{'url': 'http://www.starbucks.com/'}]}},
#   'user': {'id': '1070527',
#    'firstName': 'Starbucks',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/PM3ZCXLZIG3WZHVC.png'},
#    'type': 'chain',
#    'tips': {'count': 46},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1257275564,
#  'tips': {'count': 21,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 21,
#     'items': [{'id': '4e652becb61cd78089bb5826',
#       'createdAt': 1315253228,
#       'text': 'Try the coffee',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4e652becb61cd78089bb5826',
#       'lang': 'en',
#       'likes': {'count': 7,
#        'groups': [{'type': 'others',
#          'count': 7,
#          'items': [{'id': '4301792',
#            'firstName': 'Sheri Fresonke',
#            'lastName': 'H',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/F04Y0JNEWQAKHJCT.jpg'}},
#           {'id': '10612172',
#            'firstName': 'Tom',
#            'lastName': 'L',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/L5DB5FGEHI4SAWEI.jpg'}},
#           {'id': '45855208',
#            'firstName': 'rosario',
#            'lastName': 's',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/XAKYEDXLEALR4QKX.jpg'}},
#           {'id': '10088061',
#            'firstName': 'Manlio',
#            'lastName': 'M',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/T5PFTB12ATKCZJPX.jpg'}}]}],
#        'summary': '7 likes'},
#       'logView': True,
#       'agreeCount': 7,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '2960638',
#        'firstName': 'Mac',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2960638-OH4GHXQNFFLCJLPJ.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/4u4zJx',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 7,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 7,
#     'items': [{'id': '5145174be4b0c80a356483db',
#       'name': 'Starbucks around the world',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '5499520',
#        'firstName': 'Manon B 🌈🌺😍',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/5499520-PVYFHV0RKJIPDT2M.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/manonboisvert/list/starbucks-around-the-world',
#       'canonicalUrl': 'https://foursquare.com/manonboisvert/list/starbucks-around-the-world',
#       'createdAt': 1363482443,
#       'updatedAt': 1410148785,
#       'followers': {'count': 10},
#       'listItems': {'count': 101,
#        'items': [{'id': 'v4af080acf964a520b5dc21e3',
#          'createdAt': 1384398097}]}},
#      {'id': '4fc9377ee4b0400ad2129c1b',
#       'name': 'Drinks',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '28369735',
#        'firstName': 'Patti',
#        'lastName': 'P',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/28369735-5FBEBMYY1T1CU2IE.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/patti1313/list/drinks',
#       'canonicalUrl': 'https://foursquare.com/patti1313/list/drinks',
#       'createdAt': 1338587006,
#       'updatedAt': 1406334706,
#       'followers': {'count': 3},
#       'listItems': {'count': 49,
#        'items': [{'id': 'v4af080acf964a520b5dc21e3',
#          'createdAt': 1384637811}]}},
#      {'id': '4e845e2e7bebd842c95097bf',
#       'name': 'Must-visit Food in Pompano Beach',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '12893880',
#        'firstName': 'Mary',
#        'lastName': 'K',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W1FPIRJGV35VA2BI.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/12893880/list/mustvisit-food-in-pompano-beach',
#       'canonicalUrl': 'https://foursquare.com/user/12893880/list/mustvisit-food-in-pompano-beach',
#       'createdAt': 1317297710,
#       'updatedAt': 1317297710,
#       'followers': {'count': 1},
#       'listItems': {'count': 3,
#        'items': [{'id': 'v4af080acf964a520b5dc21e3',
#          'createdAt': 1317297710}]}},
#      {'id': '4ee65e46a69d89905ddba756',
#       'name': 'AT&T Wi-Fi Hot Spots - Starbucks #9',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '11852785',
#        'firstName': 'AT&T',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/11852785-I454F2WMF3U2VCYF'},
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/p/att/11852785/list/att-wifi-hot-spots--starbucks-9',
#       'canonicalUrl': 'https://foursquare.com/p/att/11852785/list/att-wifi-hot-spots--starbucks-9',
#       'createdAt': 1323720262,
#       'updatedAt': 1405708657,
#       'logView': True,
#       'followers': {'count': 83},
#       'listItems': {'count': 198,
#        'items': [{'id': 't4ee7a99fb634ba846b99fe3b',
#          'createdAt': 1323805080}]}}]}]},
#  'hours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Fri',
#     'includesToday': True,
#     'open': [{'renderedTime': '5:00 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '5:30 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '6:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–5:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '7:00 AM–6:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–5:00 PM'},
#      {'renderedTime': '7:00 PM–8:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–4:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–5:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. Discover & Visa)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Breakfast',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '511a58d1e4b0030487f30121',
#   'createdAt': 1360681169,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/15208664_OABwsdJqGi97y8xCZ3UQqsfGzvGJrtYGLu4X7H8oA2s.jpg',
#   'width': 720,
#   'height': 960,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '511a58d1e4b0030487f30121',
#    'value': -15198184},
#   'highlightTextColor': {'photoId': '511a58d1e4b0030487f30121', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %%
result['response']['venue']['tips']['count']
# Out:
# 21

# %%
limit = 25 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e599e8c0cc1fd001b03e50c'},
#  'response': {'tips': {'count': 21,
#    'items': [{'id': '5112675be4b0014add4b1db0',
#      'createdAt': 1360160603,
#      'text': 'Best Starbucks around, Chris is a great barista and all the other ones are so kind and helpful as well!',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5112675be4b0014add4b1db0',
#      'lang': 'en',
#      'likes': {'count': 2,
#       'groups': [{'type': 'others',
#         'count': 2,
#         'items': [{'id': '146691036',
#           'firstName': 'Ahmed',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/146691036_LWSC8Lrj_3Jr971JNzcwavYDw5Ch46GkBWpzU6MtI0NzqNbdOv0oh2OCeNEHw09gAQEVmbm-R.jpg'}},
#          {'id': '29119069',
#           'firstName': 'Chris',
#           'lastName': 'T',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/L55ZM1NSEEEWWPW0.jpg'}}]}],
#       'summary': '2 likes'},
#      'logView': True,
#      'agreeCount': 5,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '39118745',
#       'firstName': 'Mary',
#       'lastName': 'A',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/TEXR5UWN1WPRBS40.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                       text  \
# 0  Best Starbucks around, Chris is a great barista and all the other ones are so kind and helpful as well!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  5           0              5112675be4b0014add4b1db0  Mary
#
#   user.lastName  user.gender   user.id
# 0  A            NaN           39118745
